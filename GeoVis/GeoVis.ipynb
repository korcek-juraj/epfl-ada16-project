# %%
import pandas as pd
import folium
import math

# %%
input_file_name = 'tweets-predicted-values'

# %%
df = pd.read_csv(input_file_name + '.csv', sep = ';')
df.sample(5)
# Out:
#     Unnamed: 0  latitude  longitude  count  percentage-pos
# 28          28  47.35795    8.67649     24        0.904055
# 46          46  47.51668    7.58733      1        0.999770
# 2            2  46.20222    6.14569      4        0.999308
# 15          15  47.05048    8.30635    221        0.871453
# 25          25  47.29646    8.83431      4        0.891989

# %%
# Map of Switzerland
map = folium.Map(location=[46.8, 8.2], zoom_start=8, tiles='Stamen Toner')

# Add outline
state_geo = r'./ch-cantons.topojson.json'
map.choropleth(geo_path=state_geo, topojson='objects.cantons',
             fill_color='#000', fill_opacity=0.05, line_opacity=.8)

for row in df.values:
    # Add circle
    color_part = row[4]
    opacity = row[4]
    if color_part < .7:
        color_part -= .5
        opacity = 1 - opacity + .3
    red = math.floor(255 * (1 - color_part))
    others = str(255 - red)
    red = str(red)
    map.circle_marker(
                    location=[row[1], row[2]], radius=2400 * math.log(row[3]),
                    popup="Count %.0f, average happyness %.2f%%" % (row[3], row[4] * 100),
                    line_color=None,
                    fill_color="rgb(" + red + ", " + others + ", " + others + ")",
                    fill_opacity=opacity*.7)

map.save(input_file_name + '.html')
map
# Out:
# /Users/feedy/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:24: FutureWarning: circle_marker is deprecated. Use add_children(CircleMarker) instead
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;"></iframe></div></div>

# %%
"Count %f, average %.2f%%" % (123, 82.312353)
# Out:
# 'Count 123.000000, average 82.31%'
